# %%
import os, sys
import django
from datetime import datetime
sys.path.append('../') # add path to project root dir

os.environ["DJANGO_SETTINGS_MODULE"] = "flourish.settings"
from django.apps import apps as django_apps
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
from django.apps import apps as django_appsh

django.setup()
# Out:
#   * Reading config from flourish.ini
# Loading Data Encryption (init)...
#  * loading keys from /Users/salahdin/PycharmProjects/flourish/flourish/crypto_fields
#  * loading rsa.restricted.public ... Done.
#  * loading rsa.restricted.private ... Done.
#  * loading rsa.local.public ... Done.
#  * loading rsa.local.private ... Done.
#  * loading aes.local ... Done.
#  * loading aes.restricted ... Done.
#  * loading salt.local ... Done.
#  * loading salt.restricted ... Done.
#  Done loading Data Encryption (init)...
# /Users/salahdin/PycharmProjects/flourish/flourish/venv/lib/python3.10/site-packages/django_q/conf.py:139: UserWarning: Retry and timeout are misconfigured. Set retry larger than timeout,
#         failure to do so will cause the tasks to be retriggered before completion.
#         See https://django-q.readthedocs.io/en/latest/configure.html#retry for details.
#   warn(
# ...

# %%
child_pid = 'B142-040990210-2-10'

# %% [markdown]
# The problem arose because the child's V3 assent were entered incorrectly, resulting in a False value for the "is_eligible" field. Consequently, the assent signals were unable to generate dummy consent objects.

# %%
from flourish_child.models import ChildAssent, ChildDummySubjectConsent

assent_obj = ChildAssent.objects.filter(subject_identifier='B142-040990210-2-10',version='3').first()

assent_obj.initials = 'LLS'
assent_obj.hiv_testing = 'Yes'
assent_obj.save()

print(assent_obj.is_eligible)


dummy_consent = ChildDummySubjectConsent.objects.filter(subject_identifier = 'B142-040990210-2-10',version='3').first()

print(dummy_consent)



print()
# Out:
# child_assent_on_post_save
# age_in_years 11
# True
# not raw and instance.is_eligible
# True
# B142-040990210-2-10 V3
