# %%
import pandas as pd

path = '/Users/ckgathi/source/locator_data/'
fname = path + 'BHP_Maternal-Child_Pairs_Updated_11FEB2021.csv'
f = open(fname, 'r')
lines = f.readlines()
headers = lines[0]
headers = headers.strip()
headers = headers.split(',')
identifiers = []
count = 0
for line in lines:
    line = line.strip()
    line = line.split(',')
    if line[0] == 'Mpepu':
        identifiers.append(line[2])
df = pd.DataFrame(identifiers)
df.to_csv('identifiers.csv', encoding='utf-8')
len(identifiers)
# Out:
# 2523
